# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(r"sales_data.csv")
df
# Out:
#           Date     Product Region  Units Sold  Revenue  Profit
# 0   2024-01-31      Laptop  North          50    75000   15000
# 1   2024-02-29       Phone  South          70    56000   12000
# 2   2024-03-31      Tablet   East          30    24000    4000
# 3   2024-04-30  Headphones   West          90    45000    9000
# 4   2024-05-31  Smartwatch  North          60    48000    8000
# 5   2024-06-30      Camera  South          45    40000    6000
# 6   2024-07-31      Laptop   East          80    80000   16000
# 7   2024-08-31       Phone   West          65    60000   10000
# 8   2024-09-30      Tablet  North          55    50000    9000
# 9   2024-10-31  Headphones  South          75    65000   12000
# 10  2024-11-30  Smartwatch   East          40    30000    5000
# 11  2024-12-31      Camera   West          85    70000   14000

# %% [markdown]
# Line Plot — Revenue Over Time

# %%
plt.figure(figsize=(20,6))
plt.plot(df['Date'], df['Revenue'], marker='o', color='teal')
plt.title('Monthly Revenue Trend')
plt.xlabel('Date')
plt.ylabel('Revenue ($)')
plt.grid(True)
plt.show()

# %% [markdown]
# Bar Chart — Units Sold by Product

# %%
plt.figure(figsize=(8,4))
plt.bar(df['Product'], df['Units Sold'], color='orange')
plt.title('Units Sold by Product')
plt.xlabel('Product')
plt.ylabel('Units Sold')
plt.show()

# %% [markdown]
# Horizontal Bar Chart — Profit by Region

# %%
region_profit = df.groupby('Region')['Profit'].sum()
pd.DataFrame(region_profit)
# Out:
#         Profit
# Region
# East     25000
# North    32000
# South    30000
# West     33000

# %%
region_profit = df.groupby('Region')['Profit'].sum()

plt.figure(figsize=(6,4))
region_profit.plot(kind='barh', color='purple')
plt.title('Total Profit by Region')
plt.xlabel('Profit ($)')
plt.ylabel('Region')
plt.show()

# %% [markdown]
# Scatter Plot — Revenue vs Profit

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['Revenue'], df['Profit'], color='darkgreen', s=100, alpha=0.7)
plt.title('Revenue vs Profit')
plt.xlabel('Revenue ($)')
plt.ylabel('Profit ($)')
plt.grid(True)
plt.show()

# %% [markdown]
# Pie Chart — Revenue Contribution by Product

# %%
product_revenue = df.groupby('Product')['Revenue'].sum()

plt.figure(figsize=(6,6))
plt.pie(product_revenue, labels=product_revenue.index, autopct='%1.1f%%', startangle=140)
plt.title('Revenue Share by Product')
plt.show()

# %% [markdown]
# Box Plot — Profit Distribution by Region

# %%
plt.figure(figsize=(6,4))
df.boxplot(column='Profit', by='Region', grid=False, patch_artist=True)
plt.xlabel('Region')
plt.ylabel('Profit ($)')
plt.show()
